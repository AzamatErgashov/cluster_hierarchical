# %%
from IPython.display import Image

# %%
Image('iearaxik-misol.jpg', width=500)

# %% [markdown]
# # iearxik klasterlash shajara qurib klusterlab beradi

# %%
Image('iearxik-bajarilishi.jpg',width=500)

# %% [markdown]
# # iyerarxik klasterlash bolinish divise orqali yani tepadan pastga gruhlash orqali qilinadi
# # 2-chisi pastdan yuqoriga gruhlash orqali agglomerative misol pastdagi qandaydir hayvonni olib uni bitta gruhga qushamiz
